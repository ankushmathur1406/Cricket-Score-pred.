# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import os
from tqdm import tqdm

# %%
allFiles=[]
for file in os.listdir('C:\\Users\\ankus\\T-20 Score predictor\\dataset'):
    allFiles.append(os.path.join('C:\\Users\\ankus\\T-20 Score predictor\\dataset', file))

# %%
allFiles[0:10]
# Out:
# ['C:\\Users\\ankus\\T-20 Score predictor\\dataset\\1001349.yaml',
#  'C:\\Users\\ankus\\T-20 Score predictor\\dataset\\1001351.yaml',
#  'C:\\Users\\ankus\\T-20 Score predictor\\dataset\\1001353.yaml',
#  'C:\\Users\\ankus\\T-20 Score predictor\\dataset\\1004729.yaml',
#  'C:\\Users\\ankus\\T-20 Score predictor\\dataset\\1007655.yaml',
#  'C:\\Users\\ankus\\T-20 Score predictor\\dataset\\1007657.yaml',
#  'C:\\Users\\ankus\\T-20 Score predictor\\dataset\\1007659.yaml',
#  'C:\\Users\\ankus\\T-20 Score predictor\\dataset\\1019979.yaml',
#  'C:\\Users\\ankus\\T-20 Score predictor\\dataset\\1019981.yaml',
#  'C:\\Users\\ankus\\T-20 Score predictor\\dataset\\1019983.yaml']

# %%
final_data=pd.DataFrame()
cnt=1
for file in tqdm(allFiles):
    with open(file, 'r') as f:
        df=pd.json_normalize(safe_load(f))
        df['match_id']=cnt
        final_data=pd.concat([final_data,df],ignore_index=True)
        cnt=cnt+1
final_data
# Out:
# 100%|█████████▉| 4008/4009 [1:29:58<00:01,  1.35s/it]
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[5], line 5
#       3 for file in tqdm(allFiles):
#       4     with open(file, 'r') as f:
# ----> 5         df=pd.json_normalize(safe_load(f))
#       6         df['match_id']=cnt
#       7         final_data=pd.concat([final_data,df],ignore_index=True)
#
# File c:\Users\ankus\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\json\_normalize.py:445, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     443     data = list(data)
#     444 else:
# --> 445     raise NotImplementedError
#     447 # check to see if a simple recursive function is possible to
#     448 # improve performance (see #15621) but only for cases such
#     449 # as pd.Dataframe(data) or pd.Dataframe(data, sep)
#     450 if (
# ...

# %%
final_df_copy=final_data.copy()

# %%
final_data
# Out:
#                                                 innings  meta.data_version  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 1     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 2     [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...               0.91
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...               0.91
# ...                                                 ...                ...
# 4003  [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
# 4004  [{'1st innings': {'team': 'Bangladesh', 'deliv...               0.91
# 4005  [{'1st innings': {'team': 'Netherlands', 'deli...               0.91
# 4006  [{'1st innings': {'team': 'Australia', 'delive...               0.91
# 4007  [{'1st innings': {'team': 'Sri Lanka', 'delive...               0.91
#
# ...

# %%
final_data = final_data.loc[:, ['innings', 'info.dates', 'info.gender', 'info.match_type', 'info.outcome.winner', 
'info.overs', 'info.player_of_match', 'info.teams', 'info.toss.decision', 
'info.toss.winner', 'info.umpires', 'info.venue', 'match_id', 'info.city']]

# %%
final_data
# Out:
#                                                 innings    info.dates  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 1     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 2     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ...                                                 ...           ...
# 4003  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 4004  [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 4005  [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 4006  [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 4007  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#      info.gender info.match_type info.outcome.winner  info.overs  \
# ...

# %%
final_data['info.overs'].value_counts()
# Out:
# info.overs
# 20    3996
# 50      12
# Name: count, dtype: int64

# %%
final_data=final_data[final_data['info.overs']==20]
final_data.drop(columns=['info.overs', 'info.match_type'], inplace=True)
# Out:
# C:\Users\ankus\AppData\Local\Temp\ipykernel_17992\207620007.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data.drop(columns=['info.overs', 'info.match_type'], inplace=True)

# %%
final_data
# Out:
#                                                 innings    info.dates  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 1     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 2     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ...                                                 ...           ...
# 4003  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 4004  [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 4005  [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 4006  [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 4007  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#      info.gender info.outcome.winner info.player_of_match  \
# 0           male           Sri Lanka      [DAS Gunaratne]
# ...

# %%
final_data.drop(columns=['info.umpires'], inplace=True)
# Out:
# C:\Users\ankus\AppData\Local\Temp\ipykernel_17992\653243914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_data.drop(columns=['info.umpires'], inplace=True)

# %%
final_data
# Out:
#                                                 innings    info.dates  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 1     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 2     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ...                                                 ...           ...
# 4003  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 4004  [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 4005  [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 4006  [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 4007  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#      info.gender info.outcome.winner info.player_of_match  \
# 0           male           Sri Lanka      [DAS Gunaratne]
# ...

# %%
import pickle
pickle.dump(final_data, open('dataset_1new.pkl', 'wb'))

# %%
matches=pickle.load(open('dataset_1new.pkl', 'rb'))

# %%
matches
# Out:
#                                                 innings    info.dates  \
# 0     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-17]
# 1     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-19]
# 2     [{'1st innings': {'team': 'Australia', 'delive...  [2017-02-22]
# 3     [{'1st innings': {'team': 'Hong Kong', 'delive...  [2016-09-05]
# 4     [{'1st innings': {'team': 'Zimbabwe', 'deliver...  [2016-06-18]
# ...                                                 ...           ...
# 4003  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-03-04]
# 4004  [{'1st innings': {'team': 'Bangladesh', 'deliv...  [2016-03-06]
# 4005  [{'1st innings': {'team': 'Netherlands', 'deli...  [2016-02-03]
# 4006  [{'1st innings': {'team': 'Australia', 'delive...  [2016-09-06]
# 4007  [{'1st innings': {'team': 'Sri Lanka', 'delive...  [2016-09-09]
#
#      info.gender info.outcome.winner info.player_of_match  \
# 0           male           Sri Lanka      [DAS Gunaratne]
# ...

# %%
matches.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x0000021E9B620370>

# %%
matches.isnull().sum()
# Out:
# innings                   0
# info.dates                0
# info.gender               0
# info.outcome.winner     116
# info.player_of_match    399
# info.teams                0
# info.toss.decision        0
# info.toss.winner          0
# info.venue                0
# match_id                  0
# info.city               178
# dtype: int64

# %%
count = 1
delivery_df = pd.DataFrame()
for index, row in matches.iterrows():
    count+=1
    ball_of_match = []
    batsman = []
    bowler = []
    runs = []
    player_of_dismissed = []
    teams = []
    batting_team = []
    match_id = []
    city = []
    venue = []
    gender=[]
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key in ball.keys():
            match_id.append(count)
            batting_team.append(row['innings'][0]['1st innings']['team'])
            teams.append(row['info.teams'])
            ball_of_match.append(key)
            batsman.append(ball[key]['batsman'])
            bowler.append(ball[key]['bowler'])
            runs.append(ball[key]['runs']['total'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])
            gender.append(row['info.gender'])
            try:
                player_of_dismissed.append(ball[key]['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
    loop_df = pd.DataFrame({
            'match_id':match_id,
            'gender':gender,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })
    #delivery_df = delivery_df.append(loop_df)
    delivery_df=pd.concat([delivery_df,loop_df],ignore_index=True)

# %%
delivery_df
# Out:
#         match_id gender                   teams batting_team  ball  \
# 0              2   male  [Australia, Sri Lanka]    Australia   0.1
# 1              2   male  [Australia, Sri Lanka]    Australia   0.2
# 2              2   male  [Australia, Sri Lanka]    Australia   0.3
# 3              2   male  [Australia, Sri Lanka]    Australia   0.4
# 4              2   male  [Australia, Sri Lanka]    Australia   0.5
# ...          ...    ...                     ...          ...   ...
# 486720      3997   male  [Sri Lanka, Australia]    Sri Lanka  19.3
# 486721      3997   male  [Sri Lanka, Australia]    Sri Lanka  19.4
# 486722      3997   male  [Sri Lanka, Australia]    Sri Lanka  19.5
# 486723      3997   male  [Sri Lanka, Australia]    Sri Lanka  19.6
# 486724      3997   male  [Sri Lanka, Australia]    Sri Lanka  19.7
#
#                 batsman      bowler  runs player_dismissed     city  \
# 0              AJ Finch  SL Malinga     0                0      NaN
# ...

# %%
def bowling(row):
    for team in row['teams']:
        if team != row['batting_team']:
            return team

# %%
delivery_df['bowling_team'] = delivery_df.apply(bowling,axis=1)

# %%
delivery_df
# Out:
#         match_id gender                   teams batting_team  ball  \
# 0              2   male  [Australia, Sri Lanka]    Australia   0.1
# 1              2   male  [Australia, Sri Lanka]    Australia   0.2
# 2              2   male  [Australia, Sri Lanka]    Australia   0.3
# 3              2   male  [Australia, Sri Lanka]    Australia   0.4
# 4              2   male  [Australia, Sri Lanka]    Australia   0.5
# ...          ...    ...                     ...          ...   ...
# 486720      3997   male  [Sri Lanka, Australia]    Sri Lanka  19.3
# 486721      3997   male  [Sri Lanka, Australia]    Sri Lanka  19.4
# 486722      3997   male  [Sri Lanka, Australia]    Sri Lanka  19.5
# 486723      3997   male  [Sri Lanka, Australia]    Sri Lanka  19.6
# 486724      3997   male  [Sri Lanka, Australia]    Sri Lanka  19.7
#
#                 batsman      bowler  runs player_dismissed     city  \
# 0              AJ Finch  SL Malinga     0                0      NaN
# ...

# %%
delivery_df.drop(columns=['teams'],inplace=True)

# %%
teams = [
    'Australia',
    'India',
    'Bangladesh',
    'New Zealand',
    'South Africa',
    'England',
    'West Indies',
    'Pakistan',
    'Sri Lanka'    
]

# %%
delivery_df = delivery_df[delivery_df['batting_team'].isin(teams)]
delivery_df = delivery_df[delivery_df['bowling_team'].isin(teams)]

# %%
delivery_df
# Out:
#         match_id gender batting_team  ball          batsman      bowler  runs  \
# 0              2   male    Australia   0.1         AJ Finch  SL Malinga     0
# 1              2   male    Australia   0.2         AJ Finch  SL Malinga     0
# 2              2   male    Australia   0.3         AJ Finch  SL Malinga     1
# 3              2   male    Australia   0.4        M Klinger  SL Malinga     2
# 4              2   male    Australia   0.5        M Klinger  SL Malinga     0
# ...          ...    ...          ...   ...              ...         ...   ...
# 486720      3997   male    Sri Lanka  19.3  SMSM Senanayake    MA Starc     1
# 486721      3997   male    Sri Lanka  19.4      DM de Silva    MA Starc     0
# 486722      3997   male    Sri Lanka  19.5      DM de Silva    MA Starc     0
# 486723      3997   male    Sri Lanka  19.6  SMSM Senanayake    MA Starc     2
# 486724      3997   male    Sri Lanka  19.7  SMSM Senanayake    MA Starc     1
#
# ...

# %%
output = delivery_df[['match_id','gender','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
output
# Out:
#         match_id gender batting_team bowling_team  ball  runs  \
# 0              2   male    Australia    Sri Lanka   0.1     0
# 1              2   male    Australia    Sri Lanka   0.2     0
# 2              2   male    Australia    Sri Lanka   0.3     1
# 3              2   male    Australia    Sri Lanka   0.4     2
# 4              2   male    Australia    Sri Lanka   0.5     0
# ...          ...    ...          ...          ...   ...   ...
# 486720      3997   male    Sri Lanka    Australia  19.3     1
# 486721      3997   male    Sri Lanka    Australia  19.4     0
# 486722      3997   male    Sri Lanka    Australia  19.5     0
# 486723      3997   male    Sri Lanka    Australia  19.6     2
# 486724      3997   male    Sri Lanka    Australia  19.7     1
#
#        player_dismissed     city                     venue
# 0                     0      NaN  Melbourne Cricket Ground
# 1                     0      NaN  Melbourne Cricket Ground
# ...

# %%
pickle.dump(output,open('dataset_2new.pkl','wb'))

# %%
output['gender'].value_counts()
# Out:
# gender
# male      99098
# female    62981
# Name: count, dtype: int64
